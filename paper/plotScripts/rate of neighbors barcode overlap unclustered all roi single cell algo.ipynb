# %%
import pandas as pd
import scipy.spatial.distance as sci_dist
from PIL import Image
import numpy as np
from scipy.spatial import ConvexHull
import matplotlib.pyplot as plt
from matplotlib.path import Path
import os
import sys

# tools_path  = '/Users/grantkinsler/Documents/Penn/Research/SpatialBarcodes/SpatialBarcodes/analysis/tools/tools.py'
tools_path = '../helperScripts/tools.py'
# tools_path  = '/Users/grantkinsler/Documents/Penn/Research/SpatialBarcodes/analysis/tools/tools.py'

# /Users/grantkinsler/Documents/Penn/Research/SpatialBarcodes/analysis/tools/tools.py
sys.path.append(os.path.dirname(os.path.expanduser(tools_path)))
import tools as tools

Image.MAX_IMAGE_PIXELS = None
np.random.seed(0)

roi_name = 'roi_2'
data_folder = tools.roi_path_names

data_folder = '/Users/yaelheyman/RajLab Dropbox/Yael Heyman/SpatialBarcodes/ImagingData/2024-02-27_spatialbarcodes_SG_expression/projects/2024-02-27_spatialbarcodes_expression/roi_2/exports'
region_data = '/Users/YaelHeyman/RajLab Dropbox/Yael Heyman/SpatialBarcodes/ImagingData/2024-02-27_spatialbarcodes_SG_expression/processedData/Region_Data_with_Minimal_Values.csv'

cell_by_gene_path = data_folder + '/cell_by_gene_matrix_dilate10_20240718_withbarcodes_clustering_10bcs_0.2thresh.csv'
transcripts_path = data_folder + '/decode_1_withcoordinates.csv'
coords_path = data_folder + '/segmentation_1_nuclei_cellattributes.csv'
output_folder = data_folder + '/processedData'

def calculate_polygon_area(vertices):
    if not np.array_equal(vertices[0], vertices[-1]):
        vertices = np.vstack([vertices, vertices[0]])
    x0 = vertices[:-1, 0]
    y1 = vertices[1:, 1]
    y0 = vertices[:-1, 1]
    x1 = vertices[1:, 0]
    sum1 = np.sum(x0 * y1)
    sum2 = np.sum(y0 * x1)
    area = abs(sum1 - sum2) / 2.0
    return area


def max_dist(coords, ids):
    distance = sci_dist.pdist(coords[ids, :])
    dist_mat = sci_dist.squareform(distance)
    max_val = np.max(dist_mat)
    area_enclosed = calculate_polygon_area(coords[ids, :])
    return max_val, area_enclosed


def expand_polygon(vertices, expansion_distance):
    centroid = np.mean(vertices, axis=0)
    expanded_vertices = []
    for vertex in vertices:
        direction = vertex - centroid
        norm = np.linalg.norm(direction)
        if norm != 0:
            direction /= norm
        expanded_vertex = vertex + direction * expansion_distance
        expanded_vertices.append(expanded_vertex)
    return np.array(expanded_vertices)


def in_poly(polygon_indices, all_points, r=300):
    polygon_points = all_points[polygon_indices]
    if len(polygon_indices) < 3:
        if len(polygon_indices) == 1:
            center = polygon_points[0]
            distances = np.linalg.norm(all_points - center, axis=1)
            inside_indices = np.where(distances <= r)[0]
        elif len(polygon_indices) == 2:
            center = np.mean(polygon_points, axis=0)
            distances = np.linalg.norm(all_points - center, axis=1)
            inside_indices = np.where(distances <= r)[0]
    else:
        hull = ConvexHull(polygon_points)
        hull_vertices = polygon_points[hull.vertices]
        expanded_vertices = expand_polygon(hull_vertices, r / 2)
        expanded_path = Path(expanded_vertices)
        inside_indices = [i for i, point in enumerate(all_points) if expanded_path.contains_point(point)]

    inside_indices = np.setdiff1d(inside_indices, polygon_indices)  # Ensure unique and correct indices
    return inside_indices


def calc_bc_overlap(inside_indices, ids,cell_by_gene):
    overlap_info = []
    ref_barcodes = set()
    for ref_id in ids:
        # Get the barcodes and clean them up
        barcodes_str = cell_by_gene['called_barcodes'].iloc[ref_id]
        
        # Ensure barcodes are properly split and added to the set
        clean_barcodes = [barcode.strip().strip("[]'") for barcode in barcodes_str]
        ref_barcodes.update(clean_barcodes)

    for i in inside_indices:
        target_barcodes = set(cell_by_gene['called_barcodes'].iloc[i])
        target_barcodes = set([barcode.strip().strip("[]'") for barcode in target_barcodes])
        intersection = ref_barcodes & target_barcodes
        overlap_percentage = 1  if len(intersection) == len(ref_barcodes) else 0
        overlap_info.append((overlap_percentage, len(intersection)))
    return overlap_info

# %%
pixel2um = 107.11 / 1000000  # Convert pixel to micrometers
combined_df = pd.DataFrame()
region_data = pd.read_csv(region_data)
for j in range(1,4):  # Adjust range as needed
    # Dynamically construct the path
    data_folder = f"/Users/yaelheyman/RajLab Dropbox/Yael Heyman/SpatialBarcodes/ImagingData/2024-02-27_spatialbarcodes_SG_expression/projects/2024-02-27_spatialbarcodes_expression/roi_{j}/exports"
    cell_by_gene_path = os.path.join(data_folder, 'cell_by_gene_matrix_dilate10_20240718_withbarcodes_clustering_10bcs_0.2thresh.csv')
    print(data_folder)
    # Load the cell by gene data
    cell_by_gene = pd.read_csv(cell_by_gene_path, index_col=0)
        # Get reference X and Y from region_data as scalar values
    ref_x = region_data.loc[region_data['Region'] == f"Region {j}", "Min X (mm)"].iloc[0]
    ref_y = region_data.loc[region_data['Region'] == f"Region {j}", "Min Y (mm)"].iloc[0]
    
    # Correct the coordinates
    cell_by_gene['center_x'] = (cell_by_gene['center_x'] * pixel2um + ref_x)*1000
    cell_by_gene['center_y'] = (cell_by_gene['center_y'] * pixel2um + ref_y)*1000
    # Adjust the cell_id to make them unique across regions
    cell_by_gene['cell_id'] = cell_by_gene['cell_id'] + j * 100000
    
    # Concatenate to the combined DataFrame
    combined_df = pd.concat([combined_df, cell_by_gene], ignore_index=True)
# Out:
# /Users/yaelheyman/RajLab Dropbox/Yael Heyman/SpatialBarcodes/ImagingData/2024-02-27_spatialbarcodes_SG_expression/projects/2024-02-27_spatialbarcodes_expression/roi_1/exports
# /Users/yaelheyman/RajLab Dropbox/Yael Heyman/SpatialBarcodes/ImagingData/2024-02-27_spatialbarcodes_SG_expression/projects/2024-02-27_spatialbarcodes_expression/roi_2/exports
# /Users/yaelheyman/RajLab Dropbox/Yael Heyman/SpatialBarcodes/ImagingData/2024-02-27_spatialbarcodes_SG_expression/projects/2024-02-27_spatialbarcodes_expression/roi_3/exports

# %%
coords = combined_df[['center_x', 'center_y']]
# transcripts = pd.read_csv(transcripts_path, index_col=0)

# Ensure correct indexing and handling of coordinates
# coords = coords.reindex(columns=['center_x', 'center_y'])
coords = coords.to_numpy()

# Convert called_barcodes to lists if not already
combined_df['called_barcodes'] = combined_df['called_barcodes'].apply(
    lambda x: x.split(',') if isinstance(x, str) else []
)

# %%
# Check the indices of the cell_by_gene DataFrame
print("cell_by_gene indices:", combined_df.index)

# Create a dictionary to hold the indices for each unique barcode
barcode_indices = {}
for index, barcode in enumerate(combined_df['barcode_names']):
    barcode_key = barcode if barcode == barcode else 'NaN'
    if barcode_key in barcode_indices:
        barcode_indices[barcode_key].append(index)
    else:
        barcode_indices[barcode_key] = [index]

indices_list = list(barcode_indices.values())
for ids in indices_list:
    print(combined_df['barcode_names'].iloc[ids] )
# Out:
# cell_by_gene indices: RangeIndex(start=0, stop=45951, step=1)
# 0        bc_006
# 721      bc_006
# 1157     bc_006
# 1977     bc_006
# 6503     bc_006
#           ...
# 42682    bc_006
# 43642    bc_006
# 44036    bc_006
# 44152    bc_006
# 44208    bc_006
# Name: barcode_names, Length: 69, dtype: object
# 1        bc_076
# 578      bc_076
# 629      bc_076
# 927      bc_076
# 1025     bc_076
#           ...
# 40869    bc_076
# 43258    bc_076
# 43577    bc_076
# 43623    bc_076
# 43628    bc_076
# Name: barcode_names, Length: 132, dtype: object
# 2    bc_019-bc_031-bc_044-bc_046-bc_054-bc_060-bc_0...
# Name: barcode_names, dtype: object
# 3        bc_075
# 158      bc_075
# 312      bc_075
# 7539     bc_075
# 14195    bc_075
# 14735    bc_075
# 14736    bc_075
# 14775    bc_075
# 14795    bc_075
# 14806    bc_075
# 14926    bc_075
# 14973    bc_075
# 15062    bc_075
# 16029    bc_075
# 19634    bc_075
# 20860    bc_075
# 20912    bc_075
# 20962    bc_075
# 21038    bc_075
# 21437    bc_075
# 22880    bc_075
# 26904    bc_075
# 26921    bc_075
# 27078    bc_075
# 27145    bc_075
# 30346    bc_075
# 31614    bc_075
# 33526    bc_075
# 33544    bc_075
# 33548    bc_075
# 33554    bc_075
# 33653    bc_075
# 39097    bc_075
# 39319    bc_075
# 39389    bc_075
# 42260    bc_075
# 42715    bc_075
# Name: barcode_names, dtype: object
# 4        bc_084-bc_087
# 144      bc_084-bc_087
# 215      bc_084-bc_087
# 15554    bc_084-bc_087
# Name: barcode_names, dtype: object
# 5      bc_025-bc_047-bc_078-bc_084-bc_094
# 68     bc_025-bc_047-bc_078-bc_084-bc_094
# 175    bc_025-bc_047-bc_078-bc_084-bc_094
# Name: barcode_names, dtype: object
# 6        bc_025
# 275      bc_025
# 558      bc_025
# 3066     bc_025
# 3380     bc_025
#           ...
# 45321    bc_025
# 45346    bc_025
# 45526    bc_025
# 45549    bc_025
# 45659    bc_025
# Name: barcode_names, Length: 150, dtype: object
# 7        NaN
# 31       NaN
# 42       NaN
# 69       NaN
# 91       NaN
#         ...
# 45927    NaN
# 45928    NaN
# 45931    NaN
# 45937    NaN
# 45946    NaN
# Name: barcode_names, Length: 4966, dtype: object
# 8        bc_041
# 118      bc_041
# 295      bc_041
# 296      bc_041
# 300      bc_041
#           ...
# 44765    bc_041
# 44874    bc_041
# 44888    bc_041
# 45122    bc_041
# 45765    bc_041
# Name: barcode_names, Length: 215, dtype: object
#           ...
# 45241    bc_074
# 45301    bc_074
# 45338    bc_074
# 45350    bc_074
# 45448    bc_074
# Name: barcode_names, Length: 151, dtype: object
# 34       bc_058
# 130      bc_058
# 221      bc_058
# 242      bc_058
# 430      bc_058
# 4699     bc_058
# 6574     bc_058
# 9012     bc_058
# 9378     bc_058
# 9567     bc_058
# 9748     bc_058
# 10031    bc_058
# 10475    bc_058
# 10944    bc_058
# 10969    bc_058
# 11761    bc_058
# 13211    bc_058
# 15203    bc_058
# 15319    bc_058
# 15602    bc_058
# 15609    bc_058
# 15691    bc_058
# 15713    bc_058
# 16831    bc_058
# 24027    bc_058
# 24105    bc_058
# 25781    bc_058
# 30269    bc_058
# 30285    bc_058
# 30414    bc_058
# 30457    bc_058
# 30476    bc_058
# 30522    bc_058
# 31036    bc_058
# 31069    bc_058
# 31100    bc_058
# 31109    bc_058
# 31128    bc_058
# 31219    bc_058
# 34351    bc_058
# 34476    bc_058
# 37806    bc_058
# 37958    bc_058
# 37971    bc_058
# 39021    bc_058
# 40437    bc_058
# 41738    bc_058
# 43666    bc_058
# 43939    bc_058
# Name: barcode_names, dtype: object
# 36    bc_006-bc_035-bc_085-bc_087
# Name: barcode_names, dtype: object
# 37    bc_019-bc_065-bc_094
# Name: barcode_names, dtype: object
# 38       bc_009
# 63       bc_009
# 174      bc_009
# 220      bc_009
# 3306     bc_009
#           ...
# 39710    bc_009
# 41441    bc_009
# 42844    bc_009
# 42886    bc_009
# 43027    bc_009
# Name: barcode_names, Length: 79, dtype: object
# 39    bc_014-bc_066-bc_085
# Name: barcode_names, dtype: object
# 40    bc_001-bc_047-bc_059-bc_080
# Name: barcode_names, dtype: object
# 41       bc_003-bc_048-bc_074-bc_084
# 15790    bc_003-bc_048-bc_074-bc_084
# Name: barcode_names, dtype: object
# 43    bc_001-bc_002-bc_006-bc_011-bc_039-bc_052-bc_0...
# Name: barcode_names, dtype: object
# 44       bc_063-bc_068-bc_074
# 15697    bc_063-bc_068-bc_074
# Name: barcode_names, dtype: object
# 45       bc_085
# 302      bc_085
# 304      bc_085
# 568      bc_085
# 690      bc_085
#           ...
# 42628    bc_085
# 44967    bc_085
# 45039    bc_085
# 45076    bc_085
# 45375    bc_085
# Name: barcode_names, Length: 187, dtype: object
# 46       bc_050-bc_059-bc_063-bc_081-bc_092
# 95       bc_050-bc_059-bc_063-bc_081-bc_092
# 15709    bc_050-bc_059-bc_063-bc_081-bc_092
# 15819    bc_050-bc_059-bc_063-bc_081-bc_092
# Name: barcode_names, dtype: object
# 47    bc_035-bc_037-bc_041-bc_093
# Name: barcode_names, dtype: object
# 48       bc_031
# 1178     bc_031
# 1239     bc_031
# 4510     bc_031
# 6857     bc_031
#           ...
# 44943    bc_031
# 44994    bc_031
# 45271    bc_031
# 45273    bc_031
# 45339    bc_031
# Name: barcode_names, Length: 64, dtype: object
# 49     bc_030-bc_049
# 349    bc_030-bc_049
# Name: barcode_names, dtype: object
# 50     bc_022-bc_047-bc_055-bc_080
# 88     bc_022-bc_047-bc_055-bc_080
# Name: barcode_names, dtype: object
# 76       bc_070
# 271      bc_070
# 2459     bc_070
# 2524     bc_070
# 2545     bc_070
# 2602     bc_070
# 2614     bc_070
# 3565     bc_070
# 3604     bc_070
# 3648     bc_070
# 3773     bc_070
# 3787     bc_070
# 4106     bc_070
# 5838     bc_070
# 8927     bc_070
# 9000     bc_070
# 9010     bc_070
# 9024     bc_070
# 11689    bc_070
# 14525    bc_070
# 15881    bc_070
# 15947    bc_070
# 17144    bc_070
# 17316    bc_070
# 18312    bc_070
# 18359    bc_070
# 19651    bc_070
# 19684    bc_070
# 19692    bc_070
# 21482    bc_070
# 21886    bc_070
# 24465    bc_070
# 24476    bc_070
# 24943    bc_070
# 24948    bc_070
# 27859    bc_070
# 27999    bc_070
# 28592    bc_070
# 28856    bc_070
# 30399    bc_070
# 31055    bc_070
# 33238    bc_070
# 33255    bc_070
# 34470    bc_070
# 34529    bc_070
# 34531    bc_070
# 34582    bc_070
# 34616    bc_070
# 34641    bc_070
# 35458    bc_070
# 35631    bc_070
# 35658    bc_070
# 36990    bc_070
# 37006    bc_070
# 37141    bc_070
# 37210    bc_070
# 37604    bc_070
# 40747    bc_070
# 40839    bc_070
# 45461    bc_070
# Name: barcode_names, dtype: object
# 77       bc_009-bc_085
# 187      bc_009-bc_085
# 345      bc_009-bc_085
# 33699    bc_009-bc_085
# 36596    bc_009-bc_085
# 42771    bc_009-bc_085
# Name: barcode_names, dtype: object
# 78    bc_009-bc_019-bc_038-bc_041-bc_087-bc_092
# Name: barcode_names, dtype: object
# 80    bc_012-bc_073
# Name: barcode_names, dtype: object
# 81     bc_035-bc_059-bc_084
# 143    bc_035-bc_059-bc_084
# 233    bc_035-bc_059-bc_084
# 313    bc_035-bc_059-bc_084
# Name: barcode_names, dtype: object
# 83    bc_019-bc_065-bc_094-bc_096
# Name: barcode_names, dtype: object
# 84    bc_003-bc_004-bc_012-bc_024-bc_040-bc_044
# Name: barcode_names, dtype: object
# 85    bc_001-bc_003-bc_022-bc_080-bc_085
# Name: barcode_names, dtype: object
# 86       bc_009-bc_053-bc_060
# 15723    bc_009-bc_053-bc_060
# Name: barcode_names, dtype: object
# 87    bc_052-bc_086-bc_096
# Name: barcode_names, dtype: object
# 90    bc_044-bc_048-bc_083-bc_084-bc_085
# Name: barcode_names, dtype: object
# 92     bc_005-bc_019-bc_065-bc_077-bc_094-bc_096
# 137    bc_005-bc_019-bc_065-bc_077-bc_094-bc_096
# Name: barcode_names, dtype: object
# 93    bc_004-bc_012-bc_024-bc_038-bc_040-bc_044
# Name: barcode_names, dtype: object
# 94       bc_003
# 3927     bc_003
# 4429     bc_003
# 4973     bc_003
# 5163     bc_003
#           ...
# 43382    bc_003
# 44481    bc_003
# 45333    bc_003
# 45440    bc_003
# 45691    bc_003
# Name: barcode_names, Length: 76, dtype: object
# 96     bc_040-bc_052-bc_070-bc_083
# 338    bc_040-bc_052-bc_070-bc_083
# Name: barcode_names, dtype: object
# 97       bc_040-bc_074
# 119      bc_040-bc_074
# 7978     bc_040-bc_074
# 13522    bc_040-bc_074
# 13750    bc_040-bc_074
# 13769    bc_040-bc_074
# 21188    bc_040-bc_074
# 38759    bc_040-bc_074
# 38789    bc_040-bc_074
# 38791    bc_040-bc_074
# 38907    bc_040-bc_074
# 42655    bc_040-bc_074
# Name: barcode_names, dtype: object
# 99       bc_047
# 2760     bc_047
# 2934     bc_047
# 3474     bc_047
# 3476     bc_047
#           ...
# 44554    bc_047
# 44555    bc_047
# 44695    bc_047
# 44738    bc_047
# 45820    bc_047
# Name: barcode_names, Length: 128, dtype: object
# 100      bc_065-bc_094
# 23393    bc_065-bc_094
# 23906    bc_065-bc_094
# 23907    bc_065-bc_094
# 23941    bc_065-bc_094
# Name: barcode_names, dtype: object
# 101      bc_003-bc_057-bc_081
# 40251    bc_003-bc_057-bc_081
# Name: barcode_names, dtype: object
# 103      bc_052-bc_059-bc_086-bc_096
# 15743    bc_052-bc_059-bc_086-bc_096
# Name: barcode_names, dtype: object
# 105      bc_065-bc_088
# 15508    bc_065-bc_088
# 15569    bc_065-bc_088
# Name: barcode_names, dtype: object
# 106      bc_001-bc_002-bc_007-bc_065-bc_086
# 15778    bc_001-bc_002-bc_007-bc_065-bc_086
# Name: barcode_names, dtype: object
# 107    bc_025-bc_029-bc_048-bc_066-bc_084
# 142    bc_025-bc_029-bc_048-bc_066-bc_084
# 264    bc_025-bc_029-bc_048-bc_066-bc_084
# Name: barcode_names, dtype: object
# 108    bc_025-bc_043-bc_083
# Name: barcode_names, dtype: object
# 110    bc_025-bc_059-bc_092
# 153    bc_025-bc_059-bc_092
# 194    bc_025-bc_059-bc_092
# 360    bc_025-bc_059-bc_092
# Name: barcode_names, dtype: object
# 111    bc_002-bc_006-bc_011-bc_037-bc_039-bc_052-bc_0...
# Name: barcode_names, dtype: object
# 112    bc_009-bc_019-bc_044-bc_045-bc_054-bc_057-bc_0...
# Name: barcode_names, dtype: object
# 113    bc_020-bc_037-bc_093
# Name: barcode_names, dtype: object
# 117    bc_037-bc_038-bc_041
# Name: barcode_names, dtype: object
# 120      bc_030-bc_048-bc_056
# 163      bc_030-bc_048-bc_056
# 15590    bc_030-bc_048-bc_056
# 15679    bc_030-bc_048-bc_056
# 15690    bc_030-bc_048-bc_056
# 15738    bc_030-bc_048-bc_056
# 36617    bc_030-bc_048-bc_056
# 36618    bc_030-bc_048-bc_056
# Name: barcode_names, dtype: object
# 121      bc_060
# 181      bc_060
# 238      bc_060
# 601      bc_060
# 621      bc_060
#           ...
# 44658    bc_060
# 44681    bc_060
# 44824    bc_060
# 45374    bc_060
# 45400    bc_060
# Name: barcode_names, Length: 154, dtype: object
# 122      bc_053-bc_060
# 154      bc_053-bc_060
# 27390    bc_053-bc_060
# 28256    bc_053-bc_060
# 28434    bc_053-bc_060
# 28622    bc_053-bc_060
# 29305    bc_053-bc_060
# Name: barcode_names, dtype: object
# 123    bc_015-bc_074
# Name: barcode_names, dtype: object
# 124    bc_025-bc_041-bc_059-bc_083-bc_092
# Name: barcode_names, dtype: object
# 126      bc_002-bc_063-bc_066-bc_094
# 15768    bc_002-bc_063-bc_066-bc_094
# Name: barcode_names, dtype: object
# 128      bc_056
# 197      bc_056
# 429      bc_056
# 961      bc_056
# 1087     bc_056
#           ...
# 45483    bc_056
# 45492    bc_056
# 45609    bc_056
# 45671    bc_056
# 45701    bc_056
# Name: barcode_names, Length: 74, dtype: object
# 129    bc_013-bc_025-bc_030-bc_050-bc_052-bc_063-bc_0...
# Name: barcode_names, dtype: object
# 131    bc_043-bc_044-bc_083
# Name: barcode_names, dtype: object
# 132    bc_031-bc_041-bc_075
# Name: barcode_names, dtype: object
# 133    bc_004-bc_019-bc_040-bc_045-bc_078-bc_086-bc_093
# 210    bc_004-bc_019-bc_040-bc_045-bc_078-bc_086-bc_093
# Name: barcode_names, dtype: object
# 134    bc_047-bc_066-bc_085
# Name: barcode_names, dtype: object
# 135    bc_001-bc_006-bc_027-bc_041-bc_048-bc_066-bc_0...
# Name: barcode_names, dtype: object
# 138      bc_043-bc_083
# 188      bc_043-bc_083
# 196      bc_043-bc_083
# 198      bc_043-bc_083
# 199      bc_043-bc_083
# 299      bc_043-bc_083
# 306      bc_043-bc_083
# 477      bc_043-bc_083
# 15665    bc_043-bc_083
# 15707    bc_043-bc_083
# 41917    bc_043-bc_083
# 41933    bc_043-bc_083
# 42014    bc_043-bc_083
# Name: barcode_names, dtype: object
# 139    bc_001-bc_039-bc_059-bc_067-bc_078-bc_086
# 182    bc_001-bc_039-bc_059-bc_067-bc_078-bc_086
# 310    bc_001-bc_039-bc_059-bc_067-bc_078-bc_086
# 366    bc_001-bc_039-bc_059-bc_067-bc_078-bc_086
# Name: barcode_names, dtype: object
# 140    bc_041-bc_053-bc_060-bc_062-bc_073-bc_078
# Name: barcode_names, dtype: object
# 141      bc_021
# 344      bc_021
# 539      bc_021
# 650      bc_021
# 941      bc_021
# 1040     bc_021
# 1062     bc_021
# 9656     bc_021
# 10384    bc_021
# 11352    bc_021
# 15791    bc_021
# 18768    bc_021
# 19734    bc_021
# 22901    bc_021
# 26512    bc_021
# 27135    bc_021
# 28123    bc_021
# 28289    bc_021
# 28323    bc_021
# 28611    bc_021
# 28833    bc_021
# 29023    bc_021
# 42969    bc_021
# 43077    bc_021
# 44434    bc_021
# 45150    bc_021
# 45193    bc_021
# Name: barcode_names, dtype: object
# 145     bc_037-bc_041
# 1587    bc_037-bc_041
# 7294    bc_037-bc_041
# Name: barcode_names, dtype: object
# 146    bc_011-bc_013-bc_030-bc_050-bc_074
# 339    bc_011-bc_013-bc_030-bc_050-bc_074
# 496    bc_011-bc_013-bc_030-bc_050-bc_074
# 567    bc_011-bc_013-bc_030-bc_050-bc_074
# Name: barcode_names, dtype: object
# 147      bc_060-bc_074
# 1495     bc_060-bc_074
# 8669     bc_060-bc_074
# 11289    bc_060-bc_074
# 11398    bc_060-bc_074
# 12531    bc_060-bc_074
# Name: barcode_names, dtype: object
# 148    bc_031-bc_056-bc_075
# Name: barcode_names, dtype: object
# 149    bc_050-bc_063-bc_081-bc_092
# 248    bc_050-bc_063-bc_081-bc_092
# 278    bc_050-bc_063-bc_081-bc_092
# Name: barcode_names, dtype: object
# 151    bc_035-bc_050-bc_071-bc_081-bc_085-bc_092
# Name: barcode_names, dtype: object
# 152      bc_077-bc_081
# 11458    bc_077-bc_081
# 11472    bc_077-bc_081
# 15534    bc_077-bc_081
# Name: barcode_names, dtype: object
# 155     bc_040-bc_065
# 8268    bc_040-bc_065
# Name: barcode_names, dtype: object
# 156    bc_002-bc_006-bc_011-bc_037-bc_039-bc_063-bc_0...
# Name: barcode_names, dtype: object
# 157    bc_011-bc_013-bc_030-bc_040-bc_041-bc_049-bc_0...
# Name: barcode_names, dtype: object
# 159    bc_009-bc_022-bc_041-bc_047-bc_057
# 420    bc_009-bc_022-bc_041-bc_047-bc_057
# 472    bc_009-bc_022-bc_041-bc_047-bc_057
# Name: barcode_names, dtype: object
# 160    bc_050-bc_063-bc_081-bc_089-bc_092
# Name: barcode_names, dtype: object
# 161    bc_001-bc_011-bc_047-bc_052-bc_085
# Name: barcode_names, dtype: object
# 162      bc_001
# 981      bc_001
# 1939     bc_001
# 2123     bc_001
# 2204     bc_001
#           ...
# 45172    bc_001
# 45248    bc_001
# 45617    bc_001
# 45672    bc_001
# 45690    bc_001
# Name: barcode_names, Length: 145, dtype: object
# 164      bc_005
# 6594     bc_005
# 9657     bc_005
# 10823    bc_005
# 10921    bc_005
# 13201    bc_005
# 14248    bc_005
# 16072    bc_005
# 19287    bc_005
# 19364    bc_005
# 20481    bc_005
# 22517    bc_005
# 23853    bc_005
# 25800    bc_005
# 27361    bc_005
# 27477    bc_005
# 30644    bc_005
# 30649    bc_005
# 30736    bc_005
# 32897    bc_005
# 33014    bc_005
# 33082    bc_005
# 34867    bc_005
# 41740    bc_005
# 41890    bc_005
# 41910    bc_005
# 41948    bc_005
# 43119    bc_005
# 43330    bc_005
# Name: barcode_names, dtype: object
# 165    bc_002-bc_006-bc_011-bc_037-bc_039-bc_063-bc_0...
# Name: barcode_names, dtype: object
# 166    bc_031-bc_044-bc_048-bc_083-bc_084-bc_085
# Name: barcode_names, dtype: object
# 167    bc_039-bc_077-bc_081
# Name: barcode_names, dtype: object
# 169    bc_001-bc_037
# Name: barcode_names, dtype: object
# 170    bc_048-bc_052-bc_068-bc_087
# 185    bc_048-bc_052-bc_068-bc_087
# Name: barcode_names, dtype: object
# 171     bc_041-bc_062
# 9054    bc_041-bc_062
# Name: barcode_names, dtype: object
# 172    bc_033-bc_066-bc_082
# Name: barcode_names, dtype: object
# 177    bc_050-bc_059-bc_063-bc_081-bc_089-bc_092
# Name: barcode_names, dtype: object
# 179    bc_009-bc_043-bc_048-bc_073
# 277    bc_009-bc_043-bc_048-bc_073
# 464    bc_009-bc_043-bc_048-bc_073
# 476    bc_009-bc_043-bc_048-bc_073
# Name: barcode_names, dtype: object
# 180    bc_001-bc_010-bc_078-bc_085-bc_091
# Name: barcode_names, dtype: object
# 184      bc_073
# 203      bc_073
# 331      bc_073
# 623      bc_073
# 667      bc_073
#           ...
# 42384    bc_073
# 42664    bc_073
# 43145    bc_073
# 43150    bc_073
# 45758    bc_073
# Name: barcode_names, Length: 81, dtype: object
# 186    bc_050-bc_059-bc_063-bc_071-bc_081-bc_092
# Name: barcode_names, dtype: object
# 190    bc_011-bc_039-bc_047-bc_055
# Name: barcode_names, dtype: object
# 192    bc_002-bc_020-bc_022-bc_041-bc_045-bc_059-bc_085
# Name: barcode_names, dtype: object
# 193    bc_007-bc_041-bc_061-bc_095
# 239    bc_007-bc_041-bc_061-bc_095
# Name: barcode_names, dtype: object
# 195    bc_047-bc_060-bc_069-bc_095
# 260    bc_047-bc_060-bc_069-bc_095
# Name: barcode_names, dtype: object
# 200    bc_004-bc_009-bc_012-bc_014-bc_033-bc_060-bc_084
# Name: barcode_names, dtype: object
# 201    bc_008-bc_039-bc_057-bc_063
# Name: barcode_names, dtype: object
# 202      bc_069
# 1568     bc_069
# 1633     bc_069
# 2011     bc_069
# 2517     bc_069
# 3110     bc_069
# 4989     bc_069
# 6799     bc_069
# 6862     bc_069
# 6937     bc_069
# 7597     bc_069
# 7612     bc_069
# 7838     bc_069
# 8019     bc_069
# 8042     bc_069
# 8047     bc_069
# 8130     bc_069
# 8441     bc_069
# 9421     bc_069
# 10545    bc_069
# 11158    bc_069
# 11260    bc_069
# 11277    bc_069
# 14159    bc_069
# 16561    bc_069
# 17414    bc_069
# 21317    bc_069
# 21433    bc_069
# 21668    bc_069
# 21716    bc_069
# 21783    bc_069
# 22828    bc_069
# 22907    bc_069
# 23464    bc_069
# 23510    bc_069
# 23562    bc_069
# 24516    bc_069
# 26150    bc_069
# 26185    bc_069
# 26257    bc_069
# 26330    bc_069
# 26402    bc_069
# 26443    bc_069
# 32033    bc_069
# 36390    bc_069
# 36531    bc_069
# 36532    bc_069
# 36562    bc_069
# 36627    bc_069
# Name: barcode_names, dtype: object
# 204      bc_094
# 217      bc_094
# 886      bc_094
# 2161     bc_094
# 2332     bc_094
#           ...
# 40068    bc_094
# 40255    bc_094
# 40446    bc_094
# 40483    bc_094
# 40847    bc_094
# Name: barcode_names, Length: 67, dtype: object
# 205      bc_040
# 704      bc_040
# 723      bc_040
# 1067     bc_040
# 1995     bc_040
#           ...
# 44737    bc_040
# 44922    bc_040
# 45006    bc_040
# 45412    bc_040
# 45553    bc_040
# Name: barcode_names, Length: 108, dtype: object
# 206    bc_004-bc_019-bc_040-bc_078-bc_086-bc_093
# 211    bc_004-bc_019-bc_040-bc_078-bc_086-bc_093
# Name: barcode_names, dtype: object
# 207      bc_019-bc_052
# 503      bc_019-bc_052
# 538      bc_019-bc_052
# 26205    bc_019-bc_052
# 26220    bc_019-bc_052
# Name: barcode_names, dtype: object
# 208    bc_001-bc_007-bc_008-bc_009-bc_022-bc_030-bc_0...
# Name: barcode_names, dtype: object
# 213      bc_050-bc_057
# 6369     bc_050-bc_057
# 35852    bc_050-bc_057
# 42505    bc_050-bc_057
# 42521    bc_050-bc_057
# 25496    bc_002-bc_060
# 28906    bc_002-bc_060
# 29183    bc_002-bc_060
# 44486    bc_002-bc_060
# Name: barcode_names, dtype: object
# 291    bc_001-bc_027-bc_045-bc_048-bc_059-bc_060
# 355    bc_001-bc_027-bc_045-bc_048-bc_059-bc_060
# Name: barcode_names, dtype: object
# 292    bc_015-bc_039-bc_047-bc_059-bc_081-bc_083
# Name: barcode_names, dtype: object
# 293      bc_093
# 370      bc_093
# 372      bc_093
# 612      bc_093
# 1370     bc_093
#           ...
# 41461    bc_093
# 41541    bc_093
# 44077    bc_093
# 44405    bc_093
# 44428    bc_093
# Name: barcode_names, Length: 72, dtype: object
# 294    bc_013-bc_025-bc_033-bc_047-bc_057
# Name: barcode_names, dtype: object
# 297    bc_003-bc_004-bc_007-bc_012-bc_015-bc_019-bc_0...
# Name: barcode_names, dtype: object
# 298      bc_080
# 319      bc_080
# 1084     bc_080
# 1245     bc_080
# 1976     bc_080
# 2244     bc_080
# 2513     bc_080
# 3058     bc_080
# 3073     bc_080
# 3121     bc_080
# 3175     bc_080
# 3256     bc_080
# 3371     bc_080
# 7725     bc_080
# 8226     bc_080
# 10664    bc_080
# 15189    bc_080
# 15349    bc_080
# 16542    bc_080
# 16602    bc_080
# 16784    bc_080
# 17338    bc_080
# 19518    bc_080
# 19543    bc_080
# 19987    bc_080
# 20573    bc_080
# 22724    bc_080
# 22780    bc_080
# 22822    bc_080
# 30908    bc_080
# 30916    bc_080
# 30965    bc_080
# 34421    bc_080
# 34495    bc_080
# 35030    bc_080
# 35051    bc_080
# 35865    bc_080
# 36922    bc_080
# 37046    bc_080
# 38560    bc_080
# 40309    bc_080
# 40396    bc_080
# 44723    bc_080
# 44756    bc_080
# 44965    bc_080
# Name: barcode_names, dtype: object
# 307    bc_030-bc_041-bc_049-bc_062-bc_073-bc_078
# Name: barcode_names, dtype: object
# 308    bc_020-bc_056-bc_060-bc_070-bc_077-bc_083-bc_084
# Name: barcode_names, dtype: object
# 311      bc_014-bc_028-bc_031-bc_059
# 14932    bc_014-bc_028-bc_031-bc_059
# 15096    bc_014-bc_028-bc_031-bc_059
# Name: barcode_names, dtype: object
# 314    bc_004-bc_014-bc_033-bc_060-bc_084
# Name: barcode_names, dtype: object
# 315    bc_035-bc_044-bc_063-bc_078-bc_091
# 403    bc_035-bc_044-bc_063-bc_078-bc_091
# 414    bc_035-bc_044-bc_063-bc_078-bc_091
# Name: barcode_names, dtype: object
# 317    bc_041-bc_062-bc_073-bc_078
# Name: barcode_names, dtype: object
# 318    bc_028-bc_055-bc_066-bc_084
# 544    bc_028-bc_055-bc_066-bc_084
# Name: barcode_names, dtype: object
# 320    bc_009-bc_030-bc_050-bc_060-bc_066
# Name: barcode_names, dtype: object
# 321     bc_007-bc_095
# 7946    bc_007-bc_095
# Name: barcode_names, dtype: object
# 322    bc_060-bc_084-bc_086-bc_094
# 576    bc_060-bc_084-bc_086-bc_094
# Name: barcode_names, dtype: object
# 323      bc_023-bc_040
# 11215    bc_023-bc_040
# 447    bc_001-bc_015-bc_050-bc_073
# Name: barcode_names, dtype: object
# 448    bc_038-bc_052-bc_063-bc_064-bc_095
# Name: barcode_names, dtype: object
# 450      bc_044
# 474      bc_044
# 1382     bc_044
# 1829     bc_044
# 1908     bc_044
#           ...
# 43540    bc_044
# 43551    bc_044
# 43626    bc_044
# 44045    bc_044
# 44745    bc_044
# Name: barcode_names, Length: 77, dtype: object
# 451    bc_009-bc_030-bc_066
# Name: barcode_names, dtype: object
# 452    bc_068-bc_079
# 529    bc_068-bc_079
# 647    bc_068-bc_079
# 719    bc_068-bc_079
# Name: barcode_names, dtype: object
# 453      bc_024-bc_083
# 516      bc_024-bc_083
# 643      bc_024-bc_083
# 682      bc_024-bc_083
# 39417    bc_024-bc_083
# Name: barcode_names, dtype: object
# 454    bc_006-bc_024-bc_033-bc_064-bc_091
# 524    bc_006-bc_024-bc_033-bc_064-bc_091
# 641    bc_006-bc_024-bc_033-bc_064-bc_091
# Name: barcode_names, dtype: object
# 456    bc_009-bc_041-bc_047-bc_057
# 462    bc_009-bc_041-bc_047-bc_057
# Name: barcode_names, dtype: object
# 458    bc_039-bc_046-bc_067-bc_084
# Name: barcode_names, dtype: object
# 459      bc_052-bc_079
# 6395     bc_052-bc_079
# 29937    bc_052-bc_079
# 29995    bc_052-bc_079
# 37948    bc_052-bc_079
# Name: barcode_names, dtype: object
# 460    bc_014-bc_035-bc_079
# Name: barcode_names, dtype: object
# 461     bc_018-bc_041
# 5104    bc_018-bc_041
# Name: barcode_names, dtype: object
# 463    bc_044-bc_069-bc_084
# Name: barcode_names, dtype: object
# 466    bc_001-bc_003-bc_022-bc_041-bc_080-bc_085
# Name: barcode_names, dtype: object
# 467    bc_009-bc_028-bc_041-bc_047
# Name: barcode_names, dtype: object
# 469      bc_025-bc_060-bc_063
# 504      bc_025-bc_060-bc_063
# 17770    bc_025-bc_060-bc_063
# 17796    bc_025-bc_060-bc_063
# 34032    bc_025-bc_060-bc_063
# Name: barcode_names, dtype: object
# 470    bc_004-bc_038-bc_052-bc_063-bc_064-bc_074-bc_095
# Name: barcode_names, dtype: object
# 471    bc_028-bc_055-bc_066-bc_074-bc_084
# Name: barcode_names, dtype: object
# 473    bc_008-bc_039-bc_057-bc_063-bc_070-bc_083-bc_0...
# Name: barcode_names, dtype: object
# 475    bc_038-bc_052-bc_063-bc_064-bc_084-bc_086-bc_0...
# Name: barcode_names, dtype: object
# 481    bc_041-bc_060-bc_091
# 584    bc_041-bc_060-bc_091
# Name: barcode_names, dtype: object
# 483    bc_018-bc_043-bc_047-bc_053-bc_072-bc_094
# Name: barcode_names, dtype: object
# 485      bc_043
# 3579     bc_043
# 3603     bc_043
# 3636     bc_043
# 3637     bc_043
#           ...
# 42661    bc_043
# 42666    bc_043
# 42713    bc_043
# 44079    bc_043
# 45887    bc_043
# Name: barcode_names, Length: 79, dtype: object
# 486    bc_011-bc_013-bc_050-bc_074
# 559    bc_011-bc_013-bc_050-bc_074
# 646    bc_011-bc_013-bc_050-bc_074
# 742    bc_011-bc_013-bc_050-bc_074
# Name: barcode_names, dtype: object
# 487    bc_001-bc_009-bc_030-bc_050-bc_060-bc_066
# Name: barcode_names, dtype: object
# 489    bc_019-bc_066-bc_081
# Name: barcode_names, dtype: object
# 490      bc_018-bc_074
# 42665    bc_018-bc_074
# Name: barcode_names, dtype: object
# 491    bc_003-bc_009-bc_063-bc_070-bc_094
# Name: barcode_names, dtype: object
# 492    bc_008-bc_012-bc_024-bc_028-bc_039
# 760    bc_008-bc_012-bc_024-bc_028-bc_039
# Name: barcode_names, dtype: object
# 493    bc_003-bc_004-bc_014-bc_019-bc_050-bc_058-bc_0...
# Name: barcode_names, dtype: object
# 499    bc_014-bc_020-bc_029-bc_054-bc_086
# Name: barcode_names, dtype: object
# 500    bc_002-bc_004-bc_020-bc_022-bc_041-bc_045-bc_0...
# Name: barcode_names, dtype: object
# 501    bc_043-bc_046-bc_074-bc_085
# Name: barcode_names, dtype: object
# 502    bc_018-bc_052
# Name: barcode_names, dtype: object
# 505    bc_024-bc_033-bc_041-bc_060-bc_065
# Name: barcode_names, dtype: object
# 507    bc_043-bc_060-bc_068
# 547    bc_043-bc_060-bc_068
# Name: barcode_names, dtype: object
# 508    bc_003-bc_008-bc_009-bc_020-bc_025-bc_041-bc_0...
# 620    bc_003-bc_008-bc_009-bc_020-bc_025-bc_041-bc_0...
# 627    bc_003-bc_008-bc_009-bc_020-bc_025-bc_041-bc_0...
# Name: barcode_names, dtype: object
# 509    bc_029-bc_039-bc_047-bc_086
# Name: barcode_names, dtype: object
# 510    bc_029-bc_053-bc_086
# 531    bc_029-bc_053-bc_086
# Name: barcode_names, dtype: object
# 511      bc_063-bc_070
# 514      bc_063-bc_070
# 739      bc_063-bc_070
# 26985    bc_063-bc_070
# Name: barcode_names, dtype: object
# 512    bc_013-bc_019-bc_027-bc_047-bc_086
# Name: barcode_names, dtype: object
# 513      bc_071
# 594      bc_071
# 630      bc_071
# 711      bc_071
# 6830     bc_071
# 7074     bc_071
# 8105     bc_071
# 8189     bc_071
# 8263     bc_071
# 8288     bc_071
# 8400     bc_071
# 8548     bc_071
# 8645     bc_071
# 10184    bc_071
# 10296    bc_071
# 10373    bc_071
# 12133    bc_071
# 12674    bc_071
# 12719    bc_071
# 13182    bc_071
# 19904    bc_071
# 19988    bc_071
# 20016    bc_071
# 23355    bc_071
# 23530    bc_071
# 23666    bc_071
# 23702    bc_071
# 23746    bc_071
# 23768    bc_071
# 32169    bc_071
# 36124    bc_071
# 36217    bc_071
# 38399    bc_071
# 45119    bc_071
# 45664    bc_071
# 45795    bc_071
# 45854    bc_071
# Name: barcode_names, dtype: object
# 515    bc_003-bc_009-bc_011-bc_039-bc_047-bc_055-bc_074
# Name: barcode_names, dtype: object
# 517    bc_001-bc_014-bc_020-bc_045-bc_047-bc_060-bc_0...
# Name: barcode_names, dtype: object
# 518      bc_009-bc_041
# 525      bc_009-bc_041
# 526      bc_009-bc_041
# 569      bc_009-bc_041
# 582      bc_009-bc_041
# 586      bc_009-bc_041
# 666      bc_009-bc_041
# 6509     bc_009-bc_041
# 8814     bc_009-bc_041
# 9065     bc_009-bc_041
# 16352    bc_009-bc_041
# 21727    bc_009-bc_041
# 24470    bc_009-bc_041
# 33353    bc_009-bc_041
# 34578    bc_009-bc_041
# 37151    bc_009-bc_041
# 39487    bc_009-bc_041
# 39681    bc_009-bc_041
# Name: barcode_names, dtype: object
# 519    bc_003-bc_025-bc_045-bc_060
# Name: barcode_names, dtype: object
# 520    bc_002-bc_060-bc_075-bc_076-bc_085-bc_086-bc_0...
# Name: barcode_names, dtype: object
# 521    bc_060-bc_086-bc_094
# Name: barcode_names, dtype: object
# 522    bc_001-bc_014-bc_040-bc_045-bc_048-bc_060-bc_0...
# Name: barcode_names, dtype: object
# 523    bc_012-bc_035-bc_073-bc_081
# Name: barcode_names, dtype: object
# 527    bc_035-bc_044-bc_063-bc_091
# Name: barcode_names, dtype: object
# 528    bc_022-bc_031-bc_044-bc_069-bc_084
# Name: barcode_names, dtype: object
# 530    bc_011-bc_039-bc_047
# Name: barcode_names, dtype: object
# 532     bc_019-bc_081
# 5018    bc_019-bc_081
# 5019    bc_019-bc_081
# 5093    bc_019-bc_081
# 5130    bc_019-bc_081
# 5223    bc_019-bc_081
# 5499    bc_019-bc_081
# 5551    bc_019-bc_081
# Name: barcode_names, dtype: object
# 533    bc_015-bc_073
# Name: barcode_names, dtype: object
# 534      bc_077
# 645      bc_077
# 823      bc_077
# 1423     bc_077
# 1876     bc_077
#           ...
# 42154    bc_077
# 42161    bc_077
# 42234    bc_077
# 43997    bc_077
# 45903    bc_077
# Name: barcode_names, Length: 86, dtype: object
# 535    bc_033-bc_041-bc_060
# Name: barcode_names, dtype: object
# 536      bc_038-bc_041
# 613      bc_038-bc_041
# 24213    bc_038-bc_041
# 41659    bc_038-bc_041
# Name: barcode_names, dtype: object
# 537      bc_060-bc_091
# 543      bc_060-bc_091
# 4230     bc_060-bc_091
# 4272     bc_060-bc_091
# 16989    bc_060-bc_091
# 21088    bc_060-bc_091
# 21294    bc_060-bc_091
# 21352    bc_060-bc_091
# 21448    bc_060-bc_091
# 21494    bc_060-bc_091
# 21532    bc_060-bc_091
# 21614    bc_060-bc_091
# 21697    bc_060-bc_091
# 25587    bc_060-bc_091
# 25619    bc_060-bc_091
# 25639    bc_060-bc_091
# 25656    bc_060-bc_091
# 25809    bc_060-bc_091
# 31298    bc_060-bc_091
# 42955    bc_060-bc_091
# Name: barcode_names, dtype: object
# 540    bc_033-bc_063-bc_070-bc_093
# Name: barcode_names, dtype: object
# 541    bc_008-bc_091-bc_096
# Name: barcode_names, dtype: object
# 545      bc_090
# 2600     bc_090
# 5289     bc_090
# 6917     bc_090
# 8671     bc_090
# 8716     bc_090
# 8894     bc_090
# 9675     bc_090
# 10922    bc_090
# 10997    bc_090
# 11195    bc_090
# 11762    bc_090
# 11829    bc_090
# 11928    bc_090
# 12171    bc_090
# 13120    bc_090
# 13263    bc_090
# 13296    bc_090
# 13487    bc_090
# 14290    bc_090
# 14470    bc_090
# 14512    bc_090
# 14546    bc_090
# 14966    bc_090
# 17781    bc_090
# 17958    bc_090
# 25792    bc_090
# 26913    bc_090
# 26914    bc_090
# 26974    bc_090
# 27092    bc_090
# 27490    bc_090
# 27646    bc_090
# 28589    bc_090
# 30917    bc_090
# 31009    bc_090
# 31204    bc_090
# 31260    bc_090
# 35316    bc_090
# 35380    bc_090
# 35524    bc_090
# 35553    bc_090
# 35554    bc_090
# 35779    bc_090
# 36569    bc_090
# 36749    bc_090
# 38210    bc_090
# 38365    bc_090
# 38584    bc_090
# 41185    bc_090
# 41294    bc_090
# 41347    bc_090
# 44306    bc_090
# 44366    bc_090
# Name: barcode_names, dtype: object
# 546    bc_007-bc_012-bc_045-bc_048-bc_066-bc_077-bc_078
# 673    bc_007-bc_012-bc_045-bc_048-bc_066-bc_077-bc_078
# 678    bc_007-bc_012-bc_045-bc_048-bc_066-bc_077-bc_078
# 851    bc_007-bc_012-bc_045-bc_048-bc_066-bc_077-bc_078
# Name: barcode_names, dtype: object
# 548      bc_071-bc_074
# 20692    bc_071-bc_074
# Name: barcode_names, dtype: object
# 549    bc_001-bc_020-bc_067-bc_074
# 595    bc_001-bc_020-bc_067-bc_074
# Name: barcode_names, dtype: object
# 550      bc_095
# 1045     bc_095
# 1884     bc_095
# 2193     bc_095
# 2239     bc_095
#           ...
# 44201    bc_095
# 44248    bc_095
# 45140    bc_095
# 45142    bc_095
# 45326    bc_095
# Name: barcode_names, Length: 122, dtype: object
# 551    bc_003-bc_008-bc_009-bc_025-bc_045-bc_058-bc_0...
# Name: barcode_names, dtype: object
# 552    bc_024-bc_033-bc_065-bc_076
# Name: barcode_names, dtype: object
# 554    bc_014-bc_079-bc_089
# 640    bc_014-bc_079-bc_089
# Name: barcode_names, dtype: object
# 555    bc_030-bc_041-bc_071-bc_072-bc_076-bc_096
# Name: barcode_names, dtype: object
# 557      bc_046
# 618      bc_046
# 2555     bc_046
# 2977     bc_046
# 4545     bc_046
# 5266     bc_046
# 7210     bc_046
# 7237     bc_046
# 7302     bc_046
# 7320     bc_046
# 7614     bc_046
# 8203     bc_046
# 8260     bc_046
# 8302     bc_046
# 8350     bc_046
# 8392     bc_046
# 9499     bc_046
# 10034    bc_046
# 10362    bc_046
# 10367    bc_046
# 10817    bc_046
# 12066    bc_046
# 18576    bc_046
# 18580    bc_046
# 21780    bc_046
# 21816    bc_046
# 24588    bc_046
# 33404    bc_046
# 34197    bc_046
# 35281    bc_046
# 36699    bc_046
# 40318    bc_046
# 40464    bc_046
# 40468    bc_046
# 40506    bc_046
# Name: barcode_names, dtype: object
# 560      bc_045
# 566      bc_045
# 655      bc_045
# 932      bc_045
# 1192     bc_045
#           ...
# 41563    bc_045
# 41684    bc_045
# 41915    bc_045
# 42044    bc_045
# 42404    bc_045
# Name: barcode_names, Length: 62, dtype: object
# 562      bc_081-bc_095
# 592      bc_081-bc_095
# ...
# Name: barcode_names, dtype: object
# 45510    bc_001-bc_008-bc_013-bc_025-bc_035
# 45545    bc_001-bc_008-bc_013-bc_025-bc_035
# Name: barcode_names, dtype: object
# 45511    bc_013-bc_048-bc_093
# Name: barcode_names, dtype: object
# 45512    bc_024-bc_033-bc_054-bc_057
# 45821    bc_024-bc_033-bc_054-bc_057
# 45938    bc_024-bc_033-bc_054-bc_057
# Name: barcode_names, dtype: object
# 45513    bc_014-bc_033-bc_044
# 45537    bc_014-bc_033-bc_044
# Name: barcode_names, dtype: object
# 45514    bc_010-bc_027
# Name: barcode_names, dtype: object
# 45516    bc_018-bc_041-bc_057-bc_066-bc_070
# Name: barcode_names, dtype: object
# 45517    bc_003-bc_024-bc_025-bc_056-bc_090
# Name: barcode_names, dtype: object
# 45519    bc_009-bc_015-bc_019-bc_046-bc_047-bc_050
# 45552    bc_009-bc_015-bc_019-bc_046-bc_047-bc_050
# Name: barcode_names, dtype: object
# 45522    bc_022-bc_074-bc_094
# Name: barcode_names, dtype: object
# 45524    bc_009-bc_040-bc_066-bc_067-bc_087-bc_090
# Name: barcode_names, dtype: object
# 45527    bc_009-bc_011-bc_033-bc_035-bc_040-bc_041-bc_0...
# Name: barcode_names, dtype: object
# 45528    bc_040-bc_067-bc_087
# Name: barcode_names, dtype: object
# 45535    bc_013-bc_025-bc_027-bc_048-bc_052-bc_057-bc_0...
# Name: barcode_names, dtype: object
# 45536    bc_025-bc_027-bc_034-bc_048-bc_052-bc_057-bc_0...
# Name: barcode_names, dtype: object
# 45541    bc_006-bc_007-bc_057-bc_059-bc_060-bc_085
# Name: barcode_names, dtype: object
# 45547    bc_018-bc_047-bc_058-bc_066-bc_074-bc_088
# Name: barcode_names, dtype: object
# 45550    bc_044-bc_086
# 45555    bc_044-bc_086
# 45608    bc_044-bc_086
# Name: barcode_names, dtype: object
# 45551    bc_003-bc_041-bc_057-bc_066-bc_085
# Name: barcode_names, dtype: object
# 45556    bc_029-bc_060-bc_078-bc_085-bc_087-bc_093
# Name: barcode_names, dtype: object
# 45557    bc_041-bc_057-bc_066
# 45602    bc_041-bc_057-bc_066
# 45670    bc_041-bc_057-bc_066
# 45715    bc_041-bc_057-bc_066
# Name: barcode_names, dtype: object
# 45561    bc_001-bc_009-bc_030-bc_064
# Name: barcode_names, dtype: object
# 45562    bc_012-bc_015-bc_056-bc_068
# 45623    bc_012-bc_015-bc_056-bc_068
# Name: barcode_names, dtype: object
# 45567    bc_044-bc_052
# 45579    bc_044-bc_052
# 45643    bc_044-bc_052
# 45680    bc_044-bc_052
# Name: barcode_names, dtype: object
# 45568    bc_005-bc_029-bc_038-bc_085
# Name: barcode_names, dtype: object
# 45569    bc_011-bc_024-bc_035-bc_059-bc_078
# Name: barcode_names, dtype: object
# 45571    bc_014-bc_033-bc_044-bc_082-bc_084
# Name: barcode_names, dtype: object
# 45573    bc_002-bc_006-bc_050-bc_077-bc_092
# Name: barcode_names, dtype: object
# 45574    bc_001-bc_002-bc_008-bc_018-bc_040-bc_041-bc_0...
# Name: barcode_names, dtype: object
# 45576    bc_001-bc_008-bc_025-bc_045-bc_048-bc_061-bc_0...
# Name: barcode_names, dtype: object
# 45577    bc_001-bc_009-bc_012-bc_030-bc_047-bc_064
# Name: barcode_names, dtype: object
# 45581    bc_031-bc_040-bc_057-bc_065-bc_066-bc_082
# Name: barcode_names, dtype: object
# 45582    bc_015-bc_056-bc_068
# Name: barcode_names, dtype: object
# 45590    bc_002-bc_006-bc_050-bc_077-bc_086-bc_091-bc_092
# Name: barcode_names, dtype: object
# 45591    bc_001-bc_008-bc_011-bc_024-bc_025-bc_048-bc_0...
# Name: barcode_names, dtype: object
# 45593    bc_002-bc_050-bc_057
# 45675    bc_002-bc_050-bc_057
# Name: barcode_names, dtype: object
# 45594    bc_044-bc_049-bc_086
# Name: barcode_names, dtype: object
# 45599    bc_001-bc_005-bc_040-bc_056-bc_064
# Name: barcode_names, dtype: object
# 45603    bc_022-bc_035-bc_038-bc_039-bc_048-bc_058-bc_0...
# Name: barcode_names, dtype: object
# 45604    bc_001-bc_025-bc_048-bc_089
# 45811    bc_001-bc_025-bc_048-bc_089
# Name: barcode_names, dtype: object
# 45606    bc_050-bc_062-bc_068-bc_086
# Name: barcode_names, dtype: object
# 45607    bc_027-bc_030-bc_047-bc_048-bc_055-bc_057-bc_0...
# Name: barcode_names, dtype: object
# 45612    bc_022-bc_035-bc_038-bc_039-bc_058
# Name: barcode_names, dtype: object
# 45613    bc_050-bc_062-bc_068-bc_086-bc_089
# Name: barcode_names, dtype: object
# 45614    bc_001-bc_008-bc_025-bc_048-bc_052-bc_058-bc_0...
# Name: barcode_names, dtype: object
# 45618    bc_013-bc_019-bc_022-bc_023-bc_025-bc_048-bc_0...
# Name: barcode_names, dtype: object
# 45624    bc_025-bc_064
# 45705    bc_025-bc_064
# 45802    bc_025-bc_064
# Name: barcode_names, dtype: object
# 45625    bc_001-bc_024-bc_025-bc_079
# Name: barcode_names, dtype: object
# 45627    bc_009-bc_027-bc_030-bc_060-bc_083-bc_092-bc_094
# Name: barcode_names, dtype: object
# 45629    bc_001-bc_005-bc_012-bc_014-bc_033-bc_039-bc_063
# Name: barcode_names, dtype: object
# 45630    bc_025-bc_050-bc_068-bc_074-bc_087-bc_090
# Name: barcode_names, dtype: object
# 45632    bc_066-bc_088
# Name: barcode_names, dtype: object
# 45633    bc_013-bc_025-bc_027-bc_034-bc_048-bc_052-bc_0...
# Name: barcode_names, dtype: object
# 45634    bc_018-bc_047-bc_066-bc_088
# 45799    bc_018-bc_047-bc_066-bc_088
# Name: barcode_names, dtype: object
# 45635    bc_008-bc_043
# Name: barcode_names, dtype: object
# 45636    bc_018-bc_061
# Name: barcode_names, dtype: object
# 45637    bc_008-bc_080
# 45788    bc_008-bc_080
# Name: barcode_names, dtype: object
# 45638    bc_018-bc_041-bc_070
# Name: barcode_names, dtype: object
# 45639    bc_022-bc_035-bc_038
# Name: barcode_names, dtype: object
# 45641    bc_021-bc_025-bc_049-bc_050-bc_066-bc_069-bc_0...
# Name: barcode_names, dtype: object
# 45642    bc_021-bc_068-bc_084
# 45748    bc_021-bc_068-bc_084
# Name: barcode_names, dtype: object
# 45645    bc_001-bc_013-bc_026-bc_041-bc_081
# Name: barcode_names, dtype: object
# 45646    bc_002-bc_050-bc_057-bc_084
# Name: barcode_names, dtype: object
# 45647    bc_041-bc_082-bc_085
# 45870    bc_041-bc_082-bc_085
# 45876    bc_041-bc_082-bc_085
# Name: barcode_names, dtype: object
# 45648    bc_023-bc_025-bc_079
# Name: barcode_names, dtype: object
# 45649    bc_003-bc_007-bc_023-bc_033-bc_041-bc_066
# Name: barcode_names, dtype: object
# 45653    bc_031-bc_033-bc_040-bc_066
# Name: barcode_names, dtype: object
# 45655    bc_007-bc_013-bc_074
# Name: barcode_names, dtype: object
# 45656    bc_008-bc_013-bc_025-bc_044-bc_086
# Name: barcode_names, dtype: object
# 45657    bc_003-bc_041-bc_057-bc_066
# Name: barcode_names, dtype: object
# 45661    bc_022-bc_024-bc_026-bc_033-bc_035-bc_038-bc_0...
# Name: barcode_names, dtype: object
# 45662    bc_031-bc_033-bc_040-bc_057-bc_066-bc_082
# Name: barcode_names, dtype: object
# 45665    bc_001-bc_003-bc_008-bc_025-bc_044-bc_057-bc_0...
# Name: barcode_names, dtype: object
# 45666    bc_014-bc_033-bc_044-bc_059-bc_082
# Name: barcode_names, dtype: object
# 45668    bc_015-bc_060-bc_064-bc_079-bc_086
# Name: barcode_names, dtype: object
# 45677    bc_014-bc_033-bc_044-bc_059-bc_082-bc_084
# Name: barcode_names, dtype: object
# 45678    bc_035-bc_060-bc_079
# Name: barcode_names, dtype: object
# 45679    bc_009-bc_022-bc_052-bc_056
# Name: barcode_names, dtype: object
# 45681    bc_031-bc_044-bc_060-bc_093
# Name: barcode_names, dtype: object
# 45682    bc_014-bc_043-bc_045-bc_047
# Name: barcode_names, dtype: object
# 45683    bc_001-bc_025-bc_048-bc_052-bc_058-bc_061-bc_0...
# Name: barcode_names, dtype: object
# 45685    bc_033-bc_064-bc_067-bc_077
# Name: barcode_names, dtype: object
# 45686    bc_001-bc_008-bc_025-bc_048-bc_052-bc_061-bc_0...
# Name: barcode_names, dtype: object
# 45688    bc_001-bc_025-bc_048-bc_052-bc_061-bc_067
# Name: barcode_names, dtype: object
# 45693    bc_001-bc_038-bc_044-bc_086
# Name: barcode_names, dtype: object
# 45694    bc_023-bc_025-bc_064-bc_079
# Name: barcode_names, dtype: object
# 45697    bc_013-bc_025-bc_027-bc_048-bc_052-bc_057-bc_0...
# Name: barcode_names, dtype: object
# 45699    bc_005-bc_012-bc_014-bc_016-bc_024-bc_033-bc_0...
# Name: barcode_names, dtype: object
# 45700    bc_021-bc_066-bc_068-bc_084-bc_094
# Name: barcode_names, dtype: object
# 45702    bc_015-bc_035-bc_064-bc_065-bc_077-bc_079-bc_0...
# Name: barcode_names, dtype: object
# 45704    bc_021-bc_044-bc_066-bc_067-bc_088
# 45780    bc_021-bc_044-bc_066-bc_067-bc_088
# 45784    bc_021-bc_044-bc_066-bc_067-bc_088
# 45792    bc_021-bc_044-bc_066-bc_067-bc_088
# Name: barcode_names, dtype: object
# 45706    bc_011-bc_024-bc_039-bc_059
# Name: barcode_names, dtype: object
# 45707    bc_001-bc_003-bc_035-bc_045-bc_056-bc_083-bc_090
# Name: barcode_names, dtype: object
# 45709    bc_001-bc_008-bc_048-bc_052-bc_061-bc_067-bc_086
# Name: barcode_names, dtype: object
# 45714    bc_022-bc_035-bc_038-bc_039-bc_058-bc_085
# Name: barcode_names, dtype: object
# 45717    bc_013-bc_022-bc_025-bc_077
# 45775    bc_013-bc_022-bc_025-bc_077
# Name: barcode_names, dtype: object
# 45718    bc_009-bc_026-bc_048-bc_087
# Name: barcode_names, dtype: object
# 45722    bc_021-bc_030-bc_044-bc_045-bc_066-bc_067-bc_088
# Name: barcode_names, dtype: object
# 45723    bc_002-bc_036-bc_047-bc_077
# Name: barcode_names, dtype: object
# 45727    bc_001-bc_021-bc_025-bc_068-bc_084-bc_089-bc_090
# Name: barcode_names, dtype: object
# 45728    bc_008-bc_030-bc_045
# Name: barcode_names, dtype: object
# 45734    bc_041-bc_071
# Name: barcode_names, dtype: object
# 45735    bc_001-bc_030-bc_064
# Name: barcode_names, dtype: object
# 45738    bc_001-bc_008-bc_021-bc_025-bc_044-bc_048-bc_0...
# Name: barcode_names, dtype: object
# 45739    bc_009-bc_015-bc_019-bc_024-bc_040-bc_043-bc_0...
# Name: barcode_names, dtype: object
# 45740    bc_001-bc_008-bc_021-bc_025-bc_044-bc_048-bc_0...
# Name: barcode_names, dtype: object
# 45742    bc_003-bc_037-bc_041-bc_057-bc_066
# Name: barcode_names, dtype: object
# 45743    bc_026-bc_077
# Name: barcode_names, dtype: object
# 45745    bc_003-bc_011-bc_017-bc_043-bc_056-bc_067
# Name: barcode_names, dtype: object
# 45746    bc_001-bc_016-bc_030-bc_043-bc_053-bc_064-bc_077
# Name: barcode_names, dtype: object
# 45747    bc_001-bc_022-bc_056-bc_060-bc_067
# Name: barcode_names, dtype: object
# 45749    bc_050-bc_062-bc_067
# Name: barcode_names, dtype: object
# 45751    bc_019-bc_024-bc_039-bc_040-bc_043-bc_066-bc_091
# Name: barcode_names, dtype: object
# 45753    bc_027-bc_041-bc_044-bc_050-bc_052-bc_072-bc_0...
# Name: barcode_names, dtype: object
# 45755    bc_027-bc_041-bc_050-bc_072-bc_074-bc_084-bc_0...
# Name: barcode_names, dtype: object
# 45756    bc_021-bc_050-bc_057
# Name: barcode_names, dtype: object
# 45757    bc_001-bc_014-bc_033-bc_038-bc_044
# Name: barcode_names, dtype: object
# 45759    bc_015-bc_064-bc_077-bc_079-bc_082-bc_085
# Name: barcode_names, dtype: object
# 45760    bc_003-bc_024-bc_043-bc_048-bc_055-bc_056-bc_0...
# Name: barcode_names, dtype: object
# 45763    bc_009-bc_037-bc_058
# 45929    bc_009-bc_037-bc_058
# Name: barcode_names, dtype: object
# 45764    bc_044-bc_045-bc_066-bc_088
# Name: barcode_names, dtype: object
# 45769    bc_050-bc_067-bc_071
# Name: barcode_names, dtype: object
# 45771    bc_016-bc_064-bc_067
# Name: barcode_names, dtype: object
# 45772    bc_001-bc_008-bc_021-bc_025-bc_044-bc_048-bc_0...
# Name: barcode_names, dtype: object
# 45773    bc_009-bc_015-bc_019-bc_024-bc_040-bc_043-bc_0...
# Name: barcode_names, dtype: object
# 45777    bc_015-bc_068
# Name: barcode_names, dtype: object
# 45785    bc_025-bc_049-bc_066-bc_067-bc_069-bc_077-bc_0...
# Name: barcode_names, dtype: object
# 45791    bc_055-bc_073
# 45948    bc_055-bc_073
# Name: barcode_names, dtype: object
# 45793    bc_001-bc_013-bc_024-bc_030-bc_057-bc_081
# Name: barcode_names, dtype: object
# 45794    bc_044-bc_057-bc_066-bc_067-bc_088-bc_094
# Name: barcode_names, dtype: object
# 45796    bc_002-bc_013-bc_015-bc_025-bc_041-bc_043-bc_0...
# Name: barcode_names, dtype: object
# 45798    bc_022-bc_033-bc_057-bc_063-bc_068-bc_086-bc_091
# Name: barcode_names, dtype: object
# 45803    bc_011-bc_016-bc_057-bc_075
# Name: barcode_names, dtype: object
# 45805    bc_024-bc_025-bc_056-bc_090
# Name: barcode_names, dtype: object
# 45807    bc_038-bc_068-bc_083-bc_090
# Name: barcode_names, dtype: object
# 45808    bc_050-bc_058-bc_062-bc_068-bc_086-bc_087
# 45867    bc_050-bc_058-bc_062-bc_068-bc_086-bc_087
# Name: barcode_names, dtype: object
# 45810    bc_013-bc_043-bc_095
# 45881    bc_013-bc_043-bc_095
# 45910    bc_013-bc_043-bc_095
# Name: barcode_names, dtype: object
# 45812    bc_024-bc_033-bc_039-bc_041-bc_045-bc_057-bc_0...
# Name: barcode_names, dtype: object
# 45816    bc_025-bc_043-bc_066
# Name: barcode_names, dtype: object
# 45818    bc_002-bc_021-bc_041-bc_043-bc_073-bc_074
# Name: barcode_names, dtype: object
# 45822    bc_001-bc_016-bc_092
# 45899    bc_001-bc_016-bc_092
# Name: barcode_names, dtype: object
# 45823    bc_040-bc_044-bc_053
# Name: barcode_names, dtype: object
# 45825    bc_027-bc_041-bc_050-bc_072-bc_074-bc_084-bc_0...
# Name: barcode_names, dtype: object
# 45826    bc_048-bc_074-bc_084-bc_088-bc_093
# Name: barcode_names, dtype: object
# 45827    bc_018-bc_022-bc_024-bc_026-bc_041-bc_059-bc_061
# Name: barcode_names, dtype: object
# 45828    bc_022-bc_024-bc_054-bc_057
# Name: barcode_names, dtype: object
# 45834    bc_013-bc_025-bc_027-bc_041-bc_043-bc_064-bc_0...
# Name: barcode_names, dtype: object
# 45836    bc_001-bc_029-bc_030-bc_038-bc_087
# Name: barcode_names, dtype: object
# 45837    bc_019-bc_024-bc_030-bc_039-bc_040-bc_043-bc_0...
# Name: barcode_names, dtype: object
# 45839    bc_005-bc_043-bc_087-bc_092
# 45892    bc_005-bc_043-bc_087-bc_092
# Name: barcode_names, dtype: object
# 45840    bc_001-bc_004-bc_011-bc_016-bc_033-bc_055-bc_0...
# Name: barcode_names, dtype: object
# 45846    bc_010-bc_013-bc_025-bc_027-bc_048-bc_052-bc_0...
# Name: barcode_names, dtype: object
# 45849    bc_014-bc_030-bc_050
# 45851    bc_014-bc_030-bc_050
# Name: barcode_names, dtype: object
# 45850    bc_040-bc_044-bc_084-bc_092
# Name: barcode_names, dtype: object
# 45852    bc_003-bc_009-bc_015-bc_035-bc_074-bc_078
# Name: barcode_names, dtype: object
# 45855    bc_043-bc_084-bc_092
# 45879    bc_043-bc_084-bc_092
# Name: barcode_names, dtype: object
# 45857    bc_073-bc_077
# Name: barcode_names, dtype: object
# 45858    bc_022-bc_038-bc_058-bc_085
# Name: barcode_names, dtype: object
# 45861    bc_018-bc_021-bc_024-bc_025-bc_041-bc_044-bc_0...
# Name: barcode_names, dtype: object
# 45862    bc_003-bc_011-bc_039-bc_043-bc_051-bc_056-bc_067
# Name: barcode_names, dtype: object
# 45863    bc_003-bc_007-bc_009-bc_054-bc_084-bc_093
# Name: barcode_names, dtype: object
# 45868    bc_014-bc_063-bc_067
# Name: barcode_names, dtype: object
# 45871    bc_008-bc_060-bc_080
# Name: barcode_names, dtype: object
# 45878    bc_024-bc_030-bc_040-bc_043-bc_081
# Name: barcode_names, dtype: object
# 45884    bc_001-bc_022-bc_060-bc_067
# Name: barcode_names, dtype: object
# 45890    bc_022-bc_038-bc_074-bc_079-bc_082
# Name: barcode_names, dtype: object
# 45893    bc_001-bc_046-bc_052-bc_058-bc_064
# Name: barcode_names, dtype: object
# 45896    bc_002-bc_008-bc_013-bc_014-bc_015-bc_019-bc_0...
# Name: barcode_names, dtype: object
# 45900    bc_044-bc_057-bc_073
# Name: barcode_names, dtype: object
# 45902    bc_040-bc_041-bc_088
# Name: barcode_names, dtype: object
# 45904    bc_025-bc_064-bc_066-bc_095
# Name: barcode_names, dtype: object
# 45906    bc_033-bc_057-bc_094
# Name: barcode_names, dtype: object
# 45909    bc_013-bc_043
# Name: barcode_names, dtype: object
# 45914    bc_014-bc_050-bc_063
# Name: barcode_names, dtype: object
# 45918    bc_001-bc_014-bc_022-bc_030-bc_066-bc_092
# Name: barcode_names, dtype: object
# 45919    bc_022-bc_038-bc_057-bc_079-bc_082
# Name: barcode_names, dtype: object
# 45921    bc_013-bc_025-bc_027-bc_034-bc_048-bc_052-bc_0...
# Name: barcode_names, dtype: object
# 45922    bc_043-bc_087-bc_092
# Name: barcode_names, dtype: object
# 45923    bc_016-bc_064
# Name: barcode_names, dtype: object
# 45924    bc_011-bc_016-bc_057
# Name: barcode_names, dtype: object
# 45925    bc_001-bc_025-bc_079
# Name: barcode_names, dtype: object
# 45926    bc_005-bc_012-bc_014-bc_033-bc_063
# Name: barcode_names, dtype: object
# 45930    bc_001-bc_029-bc_077-bc_079-bc_087-bc_092
# Name: barcode_names, dtype: object
# 45932    bc_013-bc_062-bc_066-bc_081-bc_087
# Name: barcode_names, dtype: object
# 45933    bc_026-bc_043-bc_059-bc_066
# Name: barcode_names, dtype: object
# 45935    bc_001-bc_029-bc_067-bc_092
# Name: barcode_names, dtype: object
# 45936    bc_040-bc_041-bc_071-bc_088
# Name: barcode_names, dtype: object
# 45942    bc_040-bc_044-bc_091-bc_092
# Name: barcode_names, dtype: object
# 45943    bc_002-bc_007-bc_036-bc_037-bc_077
# Name: barcode_names, dtype: object
# 45947    bc_033-bc_039-bc_076-bc_079-bc_085-bc_088-bc_091
# Name: barcode_names, dtype: object

# %%
# Parameters
PLOT = False
r = 30  # Radius for in_poly function
# overlap_threshold = 3 # when testing for overlap between non sister cells close to sisterhood they should have over this number to be considered belonging to the sisterhood
thresholds = range(2, 11)  # Example range of threshold values to scan over
all_results = []

# Iterate over different threshold values
for thresh in thresholds:
    overlap_threshold = thresh
    all_overlap_info = []
    
    for i in range(len(combined_df)):
        if len(combined_df['called_barcodes'].iloc[i]) > thresh:
            inside_indices = in_poly(polygon_indices=[i], all_points=coords, r=r)
            overlap_info = calc_bc_overlap(inside_indices, [i], combined_df)
            all_overlap_info.extend(overlap_info)

            if PLOT:
                
                plt.figure()
                plt.scatter(coords[i, 0], coords[i, 1], c='b')
                plt.text(coords[i, 0], coords[i, 1], combined_df['barcode_names'].iloc[i], color='b', fontsize=8, ha='right', va='bottom')

                plt.scatter(coords[inside_indices, 0], coords[inside_indices, 1], c='g')
                for j, (percent, count) in zip(inside_indices, overlap_info):
                    plt.text(coords[j, 0], coords[j, 1], combined_df['barcode_names'].iloc[j], color='g', fontsize=8, ha='right', va='bottom')
                    plt.text(coords[j, 0], coords[j, 1] + 5, f"{percent:.1f}% ({count})", color='r', fontsize=8, ha='right', va='bottom')

                plt.tight_layout()
                plt.show()

                # print(combined_df['barcode_names'].iloc[ids])
                # print(combined_df[ 'barcode_names'].iloc[inside_indices])
                above_threshold = sum(1 for a, count in overlap_info if count > overlap_threshold and a==0)
                print(f"above_threshold {above_threshold}")


    # Calculate the fraction of counts above the current threshold
    above_threshold = sum(1 for a, count in all_overlap_info if count > overlap_threshold and a==0)
    total_counts = len(all_overlap_info)
    fraction_above_threshold = above_threshold / total_counts if total_counts > 0 else 0

    # Save the results for this threshold
    all_results.append((thresh, fraction_above_threshold))

    print(f"Threshold: {thresh}, Fraction of overlap counts above {overlap_threshold}: {fraction_above_threshold:.2f}")

# After the loop, you can save or further analyze `all_results` as needed.
# Example: Convert results to a DataFrame and save to CSV
results_df = pd.DataFrame(all_results, columns=['Threshold', 'FractionAboveThreshold'])
results_df.to_csv(output_folder + '/overlap_results_by_threshold_unclustered_all_rois_sc_algo.csv', index=False)

print("Results saved to overlap_results_by_threshold.csv")
# Out:
# Threshold: 2, Fraction of overlap counts above 2: 0.19
# Threshold: 3, Fraction of overlap counts above 3: 0.16
# Threshold: 4, Fraction of overlap counts above 4: 0.14
# Threshold: 5, Fraction of overlap counts above 5: 0.11
# Threshold: 6, Fraction of overlap counts above 6: 0.10
# Threshold: 7, Fraction of overlap counts above 7: 0.09
# Threshold: 8, Fraction of overlap counts above 8: 0.08
# Threshold: 9, Fraction of overlap counts above 9: 0.07
# Threshold: 10, Fraction of overlap counts above 10: 0.07
# Results saved to overlap_results_by_threshold.csv
